# %% [markdown]
# <a href="https://colab.research.google.com/github/Skarthikak/AI-Search/blob/main/ATLA_Avatar_the_Last_Airbender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Colab Dashboard Structure: "The Four Nations Archives"

# Page 1: The Title Card & Overview

# Markdown for the Title Card
from IPython.display import Markdown, display

# Function to display stylized Markdown title
def display_stylized_title(title, subtitle):
    display(Markdown(f"""
<h1 style="color:#007BFF; text-align:center; font-family: 'Times New Roman', Times, serif;">{title}</h1>
<h3 style="color:#6C757D; text-align:center; font-family: 'Times New Roman', Times, serif;">{subtitle}</h3>
"""))

display_stylized_title("Avatar: The Last Airbender - The Four Nations Archives", "Exploring the Post-War Comics")

# Markdown for the Marquee and Introduction
marquee_text = "Continuing the Journey: The Post-War Comics"
intro_text = """
Welcome to the **Four Nations Archives**, a comprehensive dashboard dedicated to the post-series comics of *Avatar: The Last Airbender*. This project serves as a digital library and data visualization tool, exploring the major plots, character developments, and canonical lore established in the comic trilogies and standalone stories that continue the adventures of Team Avatar after the events of the television series.
"""
display(Markdown(f"""
<div style="border: 2px solid #FF5733; padding: 10px; background-color: #FFEBCC; text-align: center; overflow: hidden; white-space: nowrap;">
  <span style="display: inline-block; animation: marquee 15s linear infinite; font-size: 1.2em; font-weight: bold;">{marquee_text}</span>
</div>
<style>
@keyframes marquee {{
  0%   {{ transform: translateX(100%); }}
  100% {{ transform: translateX(-100%); }}
}}
</style>
"""))
display(Markdown(intro_text))

# Image of the main Gaang
display(Markdown('### The Gaang & The Four Elements'))
display(Markdown('![Main Gaang and Four Elements](https://images.unsplash.com/photo-1628155984643-91c6e12e8b6b?q=80&w=1974&auto=format&fit=crop)'))


# Page 2: The Elements & The Avatars

# Markdown Header
display(Markdown("""
<hr>

# The Four Nations & The Avatars

<hr>
"""))

# Section 1: The Four Elements
display(Markdown('## The Four Elements'))

# Data for the four elements
import pandas as pd
df_elements = pd.DataFrame({
    'Element': ['Air', 'Water', 'Earth', 'Fire'],
    'Nation': ['Air Nomads', 'Water Tribes', 'Earth Kingdom', 'Fire Nation'],
    'Core Philosophy': ['Freedom & Spirituality', 'Change & Community', 'Endurance & Diversity', 'Power & Passion']
})

print("DataFrame for The Four Elements:")
display(df_elements)

# Visualization: Pie chart for element distribution (based on a creative interpretation of "population")
import matplotlib.pyplot as plt

# Fictional distribution data for visualization
element_distribution = [1000, 2000, 4000, 3000] # Fictional population/influence numbers
labels = df_elements['Element']
colors = ['#87CEEB', '#1E90FF', '#008000', '#FF4500']
explode = (0, 0, 0.1, 0) # Highlight the Earth Kingdom, as it's the largest

plt.figure(figsize=(8, 8))
plt.pie(element_distribution, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, textprops={'fontsize': 12, 'fontweight': 'bold'})
plt.title('Fictional Distribution of the Four Nations', fontsize=16)
plt.show()

print("\n")

# Section 2: The Avatars
display(Markdown('## The Avatars'))

# Data for the Avatars
df_avatars = pd.DataFrame({
    'Avatar': ['Korra', 'Aang', 'Roku', 'Kyoshi'],
    'Era': ['170 AG - Present', '12 BG - 153 AG', '82 BG - 12 BG', '312 BG - 82 BG'],
    'Key Accomplishment': ['Bridged Spirit World & Human World', 'Ended the Hundred Year War', 'Maintained World Peace', 'Founded the Dai Li & Kyoshi Warriors']
})

print("DataFrame for The Avatars:")
display(df_avatars)

# Page 3: Character Deep Dives

# Markdown Header for Page 3
from IPython.display import Markdown, display
import pandas as pd
import matplotlib.pyplot as plt

display(Markdown("""
<hr>

# Character Journeys: The Gaang & Beyond

<hr>
"""))

# Aang's Section
display(Markdown('### Aang: A New Kind of Balance'))
aang_plot = """
In the post-war comics, Aang's journey is no longer about defeating a single enemy but about navigating the complexities of a changing world. He grapples with the fallout of the Hundred Year War, most notably the Harmony Restoration Movement in **The Promise**, which forces him to confront the moral ambiguity of his friend Zuko's actions. His spiritual arc continues in **The Search**, where he ventures into the Spirit World to help Zuko find his mother, Ursa.
"""
display(Markdown(aang_plot))

df_aang_arcs = pd.DataFrame({
    'Comic Trilogy': ['The Promise', 'The Search', 'The Rift', 'Imbalance'],
    'Role': ['Central Protagonist', 'Central Protagonist', 'Central Protagonist', 'Central Protagonist'],
    'Key Theme': ['Political Peace', 'Spiritual Balance', 'Industrialization', 'Societal Harmony']
})

display(Markdown("#### Aang's Central Role in Comic Arcs:"))
display(df_aang_arcs)

# Toph Beifong's Section
display(Markdown('### Toph Beifong: The First Metalbending Academy'))
toph_plot = """
Toph's story evolves from a rebellious earthbender to a pioneering teacher. In **The Rift**, she establishes the first metalbending school, facing the challenges of teaching a rare skill and grappling with her own spiritual connection to the Earth. Her standalone comic, **Toph Beifong's Metalbending Academy**, further explores her unique teaching methods and the struggles of her early students.
"""
display(Markdown(toph_plot))

# Sample data for Toph's students
student_types = ['Metalbenders', 'Earthbenders', 'Firebenders', 'Waterbenders', 'Airbenders']
number_of_students = [25, 15, 2, 1, 0] # Fictional data

plt.figure(figsize=(8, 6))
plt.barh(student_types, number_of_students, color=['grey', 'brown', 'red', 'blue', 'lightblue'])
plt.xlabel('Number of Students')
plt.title('Fictional Student Population at Toph\'s Academy')
plt.show()

# Zuko's Section
display(Markdown('### Zuko: The Fire Lord\'s Burden'))
zuko_plot = """
As Fire Lord, Zuko faces immense pressure and responsibility. **The Search** is a pivotal arc for him, as he and Team Avatar search for his long-lost mother, Ursa. His journey is one of leadership and confronting his family's dark legacy. In **Smoke and Shadow**, he deals with a new threat, the Kemurikage, and political unrest within the Fire Nation, struggling to balance the past with his vision for the future.
"""
display(Markdown(zuko_plot))

# Fictional emotional data for Zuko's arc
comic_titles = ['The Promise', 'The Search', 'Smoke and Shadow', 'Imbalance']
emotional_state = [7, 4, 3, 5] # A simple scale (1-10, 10=peaceful)

plt.figure(figsize=(10, 6))
plt.plot(comic_titles, emotional_state, marker='o', linestyle='-', color='purple')
plt.title('Zuko\'s Emotional Journey (Fictional Scale)')
plt.ylabel('Emotional State (Fictional Rating)')
plt.grid(True)
plt.show()

# Katara, Sokka, and Suki's Section
display(Markdown('### The Rest of the Gaang: Katara, Sokka, and Suki'))
gaang_plot = """
While Aang, Toph, and Zuko often take the lead, the rest of the Gaang have their own important subplots. Katara's story in **North and South** explores the modernization of her home and her family's place within it. Suki's experience in prison is detailed in the standalone comic **Suki, Alone**, showing her resilience and leadership. Sokka, always the strategist, is a constant presence and source of wit across all the series.
"""
display(Markdown(gaang_plot))

df_gaang_involvement = pd.DataFrame({
    'Character': ['Katara', 'Sokka', 'Suki'],
    'Key Comics': ['North and South, The Promise', 'All Trilogies', 'Suki, Alone, Smoke and Shadow'],
    'Primary Role': ['Family & Tradition', 'Moral Support & Strategy', 'Warrior & Leader']
})

display(Markdown("#### Involvement Across Comic Series:"))
display(df_gaang_involvement)


# Page 4: The Comic Library

# Markdown Header for Page 4
display(Markdown("""
<hr>

# The A:TLA Comic Library

<hr>
"""))

# Section 1: The Main Series
display(Markdown('## The Main Series: The Trilogies'))

df_comics_main = pd.DataFrame({
    'Title': ['The Promise', 'The Search', 'The Rift', 'Smoke and Shadow', 'North and South', 'Imbalance'],
    'Author': ['Gene Luen Yang', 'Gene Luen Yang', 'Gene Luen Yang', 'Gene Luen Yang', 'Gene Luen Yang', 'Faith Erin Hicks'],
    'Release Year': [2012, 2013, 2014, 2015, 2016, 2018],
    'Key Plot': [
        'Aang and Zuko deal with the Harmony Restoration Movement.',
        'Zuko and Team Avatar search for his mother, Ursa.',
        'Aang helps Toph establish a metalbending academy.',
        'Zuko returns to the Fire Nation to face a new threat.',
        'Katara and Sokka return home to find their tribe modernizing.',
        'Team Avatar navigates the complexities of a new city.'
    ]
})

display(Markdown("#### The A:TLA Comic Trilogies:"))
display(df_comics_main)

# Visualization: Timeline of main series releases
plt.figure(figsize=(12, 4))
plt.hlines(y=1, xmin=df_comics_main['Release Year'].min() - 1, xmax=df_comics_main['Release Year'].max() + 1, color='gray', linestyle='--')
plt.plot(df_comics_main['Release Year'], [1] * len(df_comics_main), 'o', markersize=10, color='blue')
for i, row in df_comics_main.iterrows():
    plt.text(row['Release Year'], 1.05, row['Title'], ha='center', va='bottom', fontsize=10, rotation=45)
plt.title('Timeline of Main Comic Trilogy Releases')
plt.xlabel('Release Year')
plt.yticks([])
plt.box(False)
plt.show()

# Section 2: Standalone & Anthology Stories
display(Markdown('## Standalone & Anthology Stories'))

df_comics_standalone = pd.DataFrame({
    'Title': ['Katara and the Pirate\'s Silver', 'Toph Beifong\'s Metalbending Academy', 'Suki, Alone'],
    'Author': ['Faith Erin Hicks', 'Faith Erin Hicks', 'Faith Erin Hicks'],
    'Release Year': [2020, 2021, 2021],
    'Plot Summary': [
        'Katara faces off against pirates and a new enemy.',
        'Details Toph\'s early struggles with her metalbending students.',
        'Suki recounts her time in the Boiling Rock prison.'
    ]
})

display(Markdown("#### Standalone Comics:"))
display(df_comics_standalone)


import seaborn as sns

# Create a DataFrame for Aang's challenges
aang_challenges = pd.DataFrame({
    'Challenge Type': ['Political', 'Spiritual', 'Personal'],
    'Impact Score': [9, 8, 7] # Fictional impact score on a scale of 1-10
})

plt.figure(figsize=(8, 6))
sns.barplot(x='Challenge Type', y='Impact Score', data=aang_challenges, palette='Blues_d')
plt.title("Aang's Post-War Challenges (Fictional Impact)")
plt.ylabel("Impact Score")
plt.xlabel("Challenge Type")
plt.show()


bender_types = ['Metalbenders', 'Earthbenders', 'Firebenders', 'Waterbenders', 'Non-benders']
counts = [25, 15, 2, 1, 5]  # Fictional data representing her encounters

plt.figure(figsize=(8, 8))
plt.pie(counts, labels=bender_types, autopct='%1.1f%%', startangle=90, colors=['#A9A9A9', '#8B4513', '#FF4500', '#1E90FF', '#D3D3D3'])
plt.title('Distribution of Benders Encountered at Toph\'s Academy')
plt.show()

# Fictional relationship scores over time
data = {
    'Comic': ['The Promise', 'The Search', 'Smoke and Shadow', 'North and South'],
    'Aang': [8, 9, 8, 9],
    'Mai': [5, 4, 3, 4],
    'Ursa': [2, 7, 7, 7]
}

df_relationships = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.plot(df_relationships['Comic'], df_relationships['Aang'], marker='o', label='Relationship with Aang')
plt.plot(df_relationships['Comic'], df_relationships['Mai'], marker='s', label='Relationship with Mai')
plt.plot(df_relationships['Comic'], df_relationships['Ursa'], marker='^', label='Relationship with Ursa')

plt.title('Zuko\'s Key Relationships Across the Comics (Fictional Score)')
plt.xlabel('Comic Series')
plt.ylabel('Relationship Score (1-10)')
plt.legend()
plt.grid(True)
plt.show()

 # Fictional data for involvement
involvement_data = {
    'Character': ['Katara', 'Sokka', 'Suki'],
    'Adventure': [40, 60, 50],
    'Political': [40, 20, 10],
    'Personal': [20, 20, 40]
}
df_involvement = pd.DataFrame(involvement_data)
df_involvement.set_index('Character', inplace=True)

df_involvement.plot(kind='bar', stacked=True, figsize=(10, 7), color=['#1E90FF', '#8B4513', '#800080'])
plt.title('Characters\' Involvement by Comic Genre (Fictional %)')
plt.xlabel('Character')
plt.ylabel('Percentage of Involvement')
plt.xticks(rotation=0)
plt.legend(title='Genre')
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

aang_challenges = pd.DataFrame({
    'Challenge Type': ['Political', 'Spiritual', 'Personal'],
    'Impact Score': [9, 8, 7] # Fictional impact score
})

plt.figure(figsize=(6, 4))
sns.barplot(x='Challenge Type', y='Impact Score', data=aang_challenges, palette='Blues_d')
plt.title("Aang's Post-War Challenges (Fictional Impact)")
plt.ylabel("Impact Score")
plt.xlabel("Challenge Type")
plt.show()

bender_types = ['Metalbenders', 'Earthbenders', 'Firebenders', 'Waterbenders', 'Non-benders']
counts = [25, 15, 2, 1, 5]  # Fictional data

plt.figure(figsize=(6, 6))
plt.pie(counts, labels=bender_types, autopct='%1.1f%%', startangle=90, colors=['#A9A9A9', '#8B4513', '#FF4500', '#1E90FF', '#D3D3D3'])
plt.title('Distribution of Benders at Toph\'s Academy')
plt.show()


comic_titles = ['The Promise', 'The Search', 'Smoke and Shadow', 'Imbalance']
emotional_state = [7, 4, 3, 5] # Fictional scale (1-10, 10=peaceful)

plt.figure(figsize=(6, 4))
plt.plot(comic_titles, emotional_state, marker='o', linestyle='-', color='purple')
plt.title('Zuko\'s Emotional Journey (Fictional Rating)')
plt.ylabel('Emotional State')
plt.grid(True)
plt.show()

data = {
    'Comic': ['The Promise', 'The Search', 'Smoke and Shadow', 'North and South'],
    'Aang': [8, 9, 8, 9],
    'Mai': [5, 4, 3, 4],
    'Ursa': [2, 7, 7, 7]
}
df_relationships = pd.DataFrame(data)

plt.figure(figsize=(6, 4))
plt.plot(df_relationships['Comic'], df_relationships['Aang'], marker='o', label='Aang')
plt.plot(df_relationships['Comic'], df_relationships['Mai'], marker='s', label='Mai')
plt.plot(df_relationships['Comic'], df_relationships['Ursa'], marker='^', label='Ursa')
plt.title('Zuko\'s Key Relationships Across the Comics')
plt.xlabel('Comic Series')
plt.ylabel('Relationship Score (1-10)')
plt.legend()
plt.grid(True)
plt.show()

involvement_data = {
    'Character': ['Katara', 'Sokka', 'Suki'],
    'Adventure': [40, 60, 50],
    'Political': [40, 20, 10],
    'Personal': [20, 20, 40]
}
df_involvement = pd.DataFrame(involvement_data)
df_involvement.set_index('Character', inplace=True)

df_involvement.plot(kind='bar', stacked=True, figsize=(6, 5), color=['#1E90FF', '#8B4513', '#800080'])
plt.title('Characters\' Involvement by Comic Genre (Fictional %)')
plt.xlabel('Character')
plt.ylabel('Percentage of Involvement')
plt.xticks(rotation=0)
plt.legend(title='Genre')
plt.show()
# Out:
# <h1 style="color:#007BFF; text-align:center; font-family: 'Times New Roman', Times, serif;">Avatar: The Last Airbender - The Four Nations Archives</h1>
# <h3 style="color:#6C757D; text-align:center; font-family: 'Times New Roman', Times, serif;">Exploring the Post-War Comics</h3>
# <div style="border: 2px solid #FF5733; padding: 10px; background-color: #FFEBCC; text-align: center; overflow: hidden; white-space: nowrap;">
#   <span style="display: inline-block; animation: marquee 15s linear infinite; font-size: 1.2em; font-weight: bold;">Continuing the Journey: The Post-War Comics</span>
# </div>
# <style>
# @keyframes marquee {
#   0%   { transform: translateX(100%); }
#   100% { transform: translateX(-100%); }
# }
# </style>
# ...
